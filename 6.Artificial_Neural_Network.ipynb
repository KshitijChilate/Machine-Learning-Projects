# %% [markdown]
# ### MACHINE LEARNING LAB - PRACTICAL 6
# ### NAME: Kshitij Chilate
# ### ROLL NO.: 35
# ### BATCH B2
# ### DATE: 04/09/2025

# %% [markdown]
# Aim: To implement the backpropagation algorithm for machine learning
# using suitable dataset.
#
# Part I-
# Perceptron Model.
#
# Part II-
# Forward Backwards Propagation Model.

# %% [markdown]
# Targets: Part 1
#
# 1. Effect of learning rate on prediction
#
# 2. Updated weights effect for convergence

# %% [markdown]
# ### OR GATE

# %%
import numpy as np

class Perceptron:
    def __init__(self, input_size, learning_rate=0.6, epochs=20):
        self.weights = np.zeros(input_size + 1)
        self.learning_rate = learning_rate
        self.epochs = epochs

    def predict(self, inputs):
        summation = np.dot(inputs, self.weights[1:]) + self.weights[0]
        return 1 if summation > 0 else 0

    def train(self, training_inputs, labels):
        for _ in range(self.epochs):
            for inputs, label in zip(training_inputs, labels):
                prediction = self.predict(inputs)
                self.weights[1:] += self.learning_rate * (label - prediction) * inputs
                self.weights[0] += self.learning_rate * (label - prediction)


if __name__ == '__main__':

    training_inputs = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    labels = np.array([0, 1, 1, 1])

    perceptron = Perceptron(input_size=2)
    perceptron.train(training_inputs, labels)

    print("Perceptron results for OR gate:")
    print(f"Input: [0, 0], Prediction: {perceptron.predict(np.array([0, 0]))}")
    print(f"Input: [0, 1], Prediction: {perceptron.predict(np.array([0, 1]))}")
    print(f"Input: [1, 0], Prediction: {perceptron.predict(np.array([1, 0]))}")
    print(f"Input: [1, 1], Prediction: {perceptron.predict(np.array([1, 1]))}")
# Out:
# Perceptron results for OR gate:
# Input: [0, 0], Prediction: 0
# Input: [0, 1], Prediction: 1
# Input: [1, 0], Prediction: 1
# Input: [1, 1], Prediction: 1

# %% [markdown]
# ### AND GATE

# %%
training_inputs_and = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
labels_and = np.array([0, 0, 0, 1])

perceptron_and = Perceptron(input_size=2)
perceptron_and.train(training_inputs_and, labels_and)

print("\nPerceptron results for AND gate:")
print(f"Input: [0, 0], Prediction: {perceptron_and.predict(np.array([0, 0]))}")
print(f"Input: [0, 1], Prediction: {perceptron_and.predict(np.array([0, 1]))}")
print(f"Input: [1, 0], Prediction: {perceptron_and.predict(np.array([1, 0]))}")
print(f"Input: [1, 1], Prediction: {perceptron_and.predict(np.array([1, 1]))}")
# Out:
# Perceptron results for AND gate:
# Input: [0, 0], Prediction: 0
# Input: [0, 1], Prediction: 0
# Input: [1, 0], Prediction: 0
# Input: [1, 1], Prediction: 1

# %% [markdown]
# ### NAND GATE

# %%
# NAND GATE
training_inputs_nand = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
labels_nand = np.array([1, 1, 1, 0])

perceptron_nand = Perceptron(input_size=2)
perceptron_nand.train(training_inputs_nand, labels_nand)

print("\nPerceptron results for NAND gate:")
print(f"Input: [0, 0], Prediction: {perceptron_nand.predict(np.array([0, 0]))}")
print(f"Input: [0, 1], Prediction: {perceptron_nand.predict(np.array([0, 1]))}")
print(f"Input: [1, 0], Prediction: {perceptron_nand.predict(np.array([1, 0]))}")
print(f"Input: [1, 1], Prediction: {perceptron_nand.predict(np.array([1, 1]))}")
# Out:
# Perceptron results for NAND gate:
# Input: [0, 0], Prediction: 1
# Input: [0, 1], Prediction: 1
# Input: [1, 0], Prediction: 1
# Input: [1, 1], Prediction: 0

# %% [markdown]
# ### NOR

# %%
# NOR GATE
training_inputs_nor = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
labels_nor = np.array([1, 0, 0, 0])

perceptron_nor = Perceptron(input_size=2)
perceptron_nor.train(training_inputs_nor, labels_nor)

print("\nPerceptron results for NOR gate:")
print(f"Input: [0, 0], Prediction: {perceptron_nor.predict(np.array([0, 0]))}")
print(f"Input: [0, 1], Prediction: {perceptron_nor.predict(np.array([0, 1]))}")
print(f"Input: [1, 0], Prediction: {perceptron_nor.predict(np.array([1, 0]))}")
print(f"Input: [1, 1], Prediction: {perceptron_nor.predict(np.array([1, 1]))}")
# Out:
# Perceptron results for NOR gate:
# Input: [0, 0], Prediction: 1
# Input: [0, 1], Prediction: 0
# Input: [1, 0], Prediction: 0
# Input: [1, 1], Prediction: 0
